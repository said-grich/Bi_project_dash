# %%
import pandas as pd;
import json

import pandas as pd
from flatten_json import flatten

file=open('hotel_test.json');
json_file=json.load(file);
dic_flattened = pd.json_normalize(json_file,'comment',['name','location','Score',],record_prefix='Comment_')
dic_flattened
# Out:
#     Comment_name       Comment_nationality    Comment_number_of_nights  \
# 0        Camilla                    Sweden    3 nights ·  October 2019
# 1          Jamie  United States of America   5 nights ·  November 2021
# 2          Pedro                     Italy   4 nights ·  November 2021
# 3            Ben            United Kingdom    4 nights ·  October 2021
# 4         Philip               Netherlands    2 nights ·  October 2021
# ..           ...                       ...                         ...
# 122       Monika                  Slovakia      2 nights ·  April 2019
# 123   Aristeidis                    Greece  3 nights ·  September 2019
# 124    Anonymous                    France   4 nights ·  December 2019
# 125    Anonymous                   Germany  2 nights ·  September 2019
# 126    Anonymous                   Denmark   3 nights ·  February 2019
#
#     Comment_clinet_type           Comment_room_type  \
# 0                Family        Standard Double Room
# ...

# %%
file=open('hotel_test.json');
json_file=json.load(file);
json_file
# Out:
# {'name': 'Riad Riad ILayka',
#  'location': '78 Derb El Hammam quartier Mouassine , Medina, 40000 Marrakesh, Morocco',
#  'Score': '9.5',
#  'facility': ['Free WiFi',
#   'Airport shuttle',
#   'Family rooms',
#   'Restaurant',
#   'Non-smoking rooms',
#   'Pet friendly',
#   'Bar'],
#  'sous_Category': {'Staff ': '10',
#   'Facilities': '9.4',
#   'Cleanliness ': '9.8',
#   'Comfort': '9.6',
#   'Value for money': '9.3',
#   'Location': '9.5',
#   'Free WiFi ': '9.4'},
#  'comment': [{'name': 'Camilla',
#    'nationality': 'Sweden',
#    'number_of_nights': '3 nights ·  October 2019',
#    'clinet_type': 'Family',
#    'room_type': 'Standard Double Room',
#    'review_date': 'Reviewed: November 24, 2019',
#    'visite_date': 'October 2019',
# ...
